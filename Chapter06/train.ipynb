# %% [markdown]
# ## Distributed training
#
# In order to see the benefit of using distributed training, we'll first get a couple of benchmarks for training time and model performance.
#
# Adding comments.

# %% [markdown]
# ### XGBoost baseline

# %%
s3_bucket = 'rdtest-data'
s3_prefix = 'prepared_parquet4'

# %%
import sagemaker
import boto3
from sagemaker import image_uris
from sagemaker.session import Session
from sagemaker.inputs import TrainingInput
region = 'us-east-1'

# %%
# define the data type and paths to the training and validation datasets
content_type = "csv"
train_input = TrainingInput("s3://{}/{}/{}/".format(s3_bucket, s3_prefix, 'train'), content_type=content_type, distribution='ShardedByS3Key')
validation_input = TrainingInput("s3://{}/{}/{}/".format(s3_bucket, s3_prefix, 'validation'), content_type=content_type, distribution='ShardedByS3Key')

# %%
# initialize hyperparameters
hyperparameters = {
        "max_depth":"5",
        "eta":"0.2",
        "gamma":"4",
        "min_child_weight":"6",
        "subsample":"0.7",
        "objective":"reg:squarederror",
        "num_round":"5"}

# set an output path where the trained model will be saved
m_prefix = 'baseline'
output_path = 's3://{}/{}/{}/output'.format(s3_bucket, m_prefix, 'xgboost')

# this line automatically looks for the XGBoost image URI and builds an XGBoost container.
# specify the repo_version depending on your preference.
xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.2-1")

# construct a SageMaker estimator that calls the xgboost-container
estimator = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=sagemaker.get_execution_role(),
                                          instance_count=1, 
                                          instance_type='ml.m5.12xlarge', 
                                          volume_size=200, # 5 GB 
                                          output_path=output_path)



# execute the XGBoost training job
estimator.fit({'train': train_input, 'validation': validation_input})

# %% [markdown]
# XGBoost gives us a training time of 1157 seconds and Validation RMSE of 1.33505.

# %% [markdown]
# ### PyTorch baseline
#
# Note that we use a simple CSV data loader that reads the entire data set into memory. If that proves infeasible, consider using a more sophisticated CSV loader or a [Redis-based loader](https://github.com/RedisAI/RedisAI).

# %% [markdown]
# * Move to device outside of model

# %%
train_instance_type = "ml.p3.16xlarge"

# %%
from sagemaker.pytorch import PyTorch

pt_estimator = PyTorch(
    entry_point="train_pytorch.py",
    source_dir="code",
    role=sagemaker.get_execution_role(),
    instance_count=2,
    instance_type=train_instance_type,
    framework_version="1.6",
    py_version="py3",
    volume_size=1024
)

# %%
ptrain = "s3://rdtest-data/prepared_parquet4/train/part-00424-5a7f35ae-f02b-44f4-84e6-1063c134015d-c000.csv"
pvalid = "s3://rdtest-data/prepared_parquet4/validation/part-00424-ab5c94f8-354e-42ff-8e41-39c36d5e3c30-c000.csv"

# %%
pt_estimator.fit({'train': ptrain, 'test': pvalid})

# %%
pt_estimator.fit({'train': train_input, 'test': validation_input})

# %% [markdown]
# PyTorch gives us a training time of 6931 seconds and Validation RMSE of 3.43.  We only used 5 of the files and 1 epoch.

# %% [markdown]
# ### PyTorch with distributed library
#
# If you want to use multiple instances, use ml.p4dn.24xlarge or ml.p4d.24xlarge.

# %%
train_instance_type_dist = "ml.p3.16xlarge"

# %%
train_input_l = TrainingInput("s3://{}/{}/{}/".format(s3_bucket, s3_prefix, 'train'), content_type=content_type)
validation_input_l = TrainingInput("s3://{}/{}/{}/".format(s3_bucket, s3_prefix, 'validation'), content_type=content_type)

# %%
s3_prefix = 'prepared_parquet4_p'
train_input = TrainingInput("s3://{}/{}/{}/".format(s3_bucket, s3_prefix, 'train'), content_type=content_type, distribution='ShardedByS3Key')
validation_input = TrainingInput("s3://{}/{}/{}/".format(s3_bucket, s3_prefix, 'validation'), content_type=content_type, distribution='ShardedByS3Key')

# %%
from sagemaker.pytorch import PyTorch
pt_dist_estimator = PyTorch(
    entry_point="train_pytorch_dist.py",
    source_dir="code",
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type=train_instance_type_dist,
    framework_version="1.8.1",
    py_version="py36",
    volume_size=256,
    distribution={"smdistributed": {"dataparallel": {"enabled": True}}},
    debugger_hook_config=False,
    disable_profiler=True
)

# %%
pt_dist_estimator.fit({'train': ptrain, 'test': pvalid})

# %%
pt_dist_estimator.fit({'train': train_input, 'test': validation_input})
# Out:
# 2021-06-14 17:38:23 Starting - Starting the training job...
# 2021-06-14 17:38:25 Starting - Launching requested ML instances............
# 2021-06-14 17:40:25 Starting - Preparing the instances for training......
# 2021-06-14 17:41:50 Downloading - Downloading input data......
# 2021-06-14 17:42:54 Training - Downloading the training image.....................
# 2021-06-14 17:46:21 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-06-14 17:46:22,064 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-06-14 17:46:22,142 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-06-14 17:46:23,581 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel
# 2021-06-14 17:46:23,582 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-06-14 17:46:24,317 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-06-14 17:46:24,317 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2021-06-14 17:46:24,321 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2021-06-14 17:46:24,321 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2021-06-14 17:46:24,321 sagemaker-training-toolkit INFO     Host: ['algo-1']
# 2021-06-14 17:46:24,325 sagemaker-training-toolkit INFO     instance type: ml.p3.16xlarge
# 2021-06-14 17:46:24,404 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_distributed_dataparallel_enabled": true,
#         "sagemaker_distributed_dataparallel_custom_mpi_options": "",
#         "sagemaker_instance_type": "ml.p3.16xlarge"
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-06-14-17-38-22-684",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-102165494304/pytorch-training-2021-06-14-17-38-22-684/source/sourcedir.tar.gz",
#     "module_name": "train_pytorch_dist",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_pytorch_dist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=train_pytorch_dist.py
# SM_FRAMEWORK_PARAMS={"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p3.16xlarge"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_pytorch_dist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-102165494304/pytorch-training-2021-06-14-17-38-22-684/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p3.16xlarge"},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"},"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-06-14-17-38-22-684","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-102165494304/pytorch-training-2021-06-14-17-38-22-684/source/sourcedir.tar.gz","module_name":"train_pytorch_dist","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_pytorch_dist.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1 -np 8 --allow-run-as-root --tag-output --oversubscribe -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -mca plm_rsh_num_concurrent 1 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x SMDATAPARALLEL_USE_SINGLENODE=1 -x FI_PROVIDER=efa -x RDMAV_FORK_SAFE=1 -x LD_PRELOAD=/opt/conda/lib/python3.6/site-packages/gethostname.cpython-36m-x86_64-linux-gnu.so smddprun /opt/conda/bin/python3.6 -m mpi4py train_pytorch_dist.py
#
#
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:509:509 [0] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Using network Socket
# [1,0]<stdout>:NCCL version 2.7.8+cuda11.1
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Bootstrap : Using [0]eth0:10.2.75.81<0>
# [1,1]<stdout>:
# [1,1]<stdout>:algo-1:38:38 [1] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,2]<stdout>:
# [1,2]<stdout>:algo-1:40:40 [2] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,3]<stdout>:
# [1,3]<stdout>:algo-1:42:42 [3] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,4]<stdout>:
# [1,4]<stdout>:algo-1:44:44 [4] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,5]<stdout>:
# [1,5]<stdout>:algo-1:46:46 [5] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,6]<stdout>:
# [1,6]<stdout>:algo-1:47:47 [6] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,7]<stdout>:
# [1,7]<stdout>:algo-1:48:48 [7] find_ofi_provider:542 NCCL WARN NET/OFI Couldn't find any optimal provider
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Using network Socket
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Using network Socket
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Using network Socket
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Using network Socket
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Using network Socket
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Using network Socket
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO NET/Socket : Using [0]eth0:10.2.75.81<0>
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Using network Socket
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Trees [0] 4/-1/-1->7->6|6->7->4/-1/-1 [1] 4/-1/-1->7->6|6->7->4/-1/-1 [2] 6/-1/-1->7->4|4->7->6/-1/-1 [3] 6/-1/-1->7->4|4->7->6/-1/-1 [4] 5/-1/-1->7->3|3->7->5/-1/-1 [5] 3/-1/-1->7->5|5->7->3/-1/-1 [6] 4/-1/-1->7->6|6->7->4/-1/-1 [7] 4/-1/-1->7->6|6->7->4/-1/-1 [8] 6/-1/-1->7->4|4->7->6/-1/-1 [9] 6/-1/-1->7->4|4->7->6/-1/-1 [10] 5/-1/-1->7->3|3->7->5/-1/-1 [11] 3/-1/-1->7->5|5->7->3/-1/-1
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 00/12 :    0   3   2   1   5   6   7   4
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 01/12 :    0   3   2   1   5   6   7   4
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 02/12 :    0   4   7   6   5   1   2   3
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 03/12 :    0   4   7   6   5   1   2   3
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Trees [0] 5/-1/-1->1->2|2->1->5/-1/-1 [1] 5/-1/-1->1->2|2->1->5/-1/-1 [2] 2/-1/-1->1->5|5->1->2/-1/-1 [3] 2/-1/-1->1->5|5->1->2/-1/-1 [4] 3/-1/-1->1->0|0->1->3/-1/-1 [5] -1/-1/-1->1->3|3->1->-1/-1/-1 [6] 5/-1/-1->1->2|2->1->5/-1/-1 [7] 5/-1/-1->1->2|2->1->5/-1/-1 [8] 2/-1/-1->1->5|5->1->2/-1/-1 [9] 2/-1/-1->1->5|5->1->2/-1/-1 [10] 3/-1/-1->1->0|0->1->3/-1/-1 [11] -1/-1/-1->1->3|3->1->-1/-1/-1
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Trees [0] 1/-1/-1->2->3|3->2->1/-1/-1 [1] 1/-1/-1->2->3|3->2->1/-1/-1 [2] 3/-1/-1->2->1|1->2->3/-1/-1 [3] 3/-1/-1->2->1|1->2->3/-1/-1 [4] -1/-1/-1->2->6|6->2->-1/-1/-1 [5] 6/-1/-1->2->0|0->2->6/-1/-1 [6] 1/-1/-1->2->3|3->2->1/-1/-1 [7] 1/-1/-1->2->3|3->2->1/-1/-1 [8] 3/-1/-1->2->1|1->2->3/-1/-1 [9] 3/-1/-1->2->1|1->2->3/-1/-1 [10] -1/-1/-1->2->6|6->2->-1/-1/-1 [11] 6/-1/-1->2->0|0->2->6/-1/-1
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Trees [0] -1/-1/-1->4->7|7->4->-1/-1/-1 [1] -1/-1/-1->4->7|7->4->-1/-1/-1 [2] 7/-1/-1->4->0|0->4->7/-1/-1 [3] 7/-1/-1->4->0|0->4->7/-1/-1 [4] 6/-1/-1->4->5|5->4->6/-1/-1 [5] 5/-1/-1->4->6|6->4->5/-1/-1 [6] -1/-1/-1->4->7|7->4->-1/-1/-1 [7] -1/-1/-1->4->7|7->4->-1/-1/-1 [8] 7/-1/-1->4->0|0->4->7/-1/-1 [9] 7/-1/-1->4->0|0->4->7/-1/-1 [10] 6/-1/-1->4->5|5->4->6/-1/-1 [11] 5/-1/-1->4->6|6->4->5/-1/-1
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 04/12 :    0   1   3   7   5   4   6   2
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 05/12 :    0   2   6   4   5   7   3   1
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Trees [0] 2/-1/-1->3->0|0->3->2/-1/-1 [1] 2/-1/-1->3->0|0->3->2/-1/-1 [2] -1/-1/-1->3->2|2->3->-1/-1/-1 [3] -1/-1/-1->3->2|2->3->-1/-1/-1 [4] 7/-1/-1->3->1|1->3->7/-1/-1 [5] 1/-1/-1->3->7|7->3->1/-1/-1 [6] 2/-1/-1->3->0|0->3->2/-1/-1 [7] 2/-1/-1->3->0|0->3->2/-1/-1 [8] -1/-1/-1->3->2|2->3->-1/-1/-1 [9] -1/-1/-1->3->2|2->3->-1/-1/-1 [10] 7/-1/-1->3->1|1->3->7/-1/-1 [11] 1/-1/-1->3->7|7->3->1/-1/-1
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 06/12 :    0   3   2   1   5   6   7   4
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Trees [0] 6/-1/-1->5->1|1->5->6/-1/-1 [1] 6/-1/-1->5->1|1->5->6/-1/-1 [2] 1/-1/-1->5->6|6->5->1/-1/-1 [3] 1/-1/-1->5->6|6->5->1/-1/-1 [4] 4/-1/-1->5->7|7->5->4/-1/-1 [5] 7/-1/-1->5->4|4->5->7/-1/-1 [6] 6/-1/-1->5->1|1->5->6/-1/-1 [7] 6/-1/-1->5->1|1->5->6/-1/-1 [8] 1/-1/-1->5->6|6->5->1/-1/-1 [9] 1/-1/-1->5->6|6->5->1/-1/-1 [10] 4/-1/-1->5->7|7->5->4/-1/-1 [11] 7/-1/-1->5->4|4->5->7/-1/-1
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO
] -> 0[170] via P2P/IPC
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 07 : 0[170] -> 3[1a0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 07 : 3[1a0] -> 2[190] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 07 : 2[190] -> 1[180] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 07 : 7[1e0] -> 4[1b0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 07 : 1[180] -> 5[1c0] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 07 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 07 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 07 : 4[1b0] -> 7[1e0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 07 : 3[1a0] -> 0[170] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 07 : 2[190] -> 3[1a0] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 07 : 7[1e0] -> 6[1d0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 07 : 1[180] -> 2[190] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 07 : 6[1d0] -> 5[1c0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 07 : 5[1c0] -> 1[180] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 08 : 4[1b0] -> 7[1e0] via P2P/IPC
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 08 : 0[170] -> 4[1b0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 08 : 3[1a0] -> 0[170] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 08 : 2[190] -> 3[1a0] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 08 : 7[1e0] -> 6[1d0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 08 : 1[180] -> 2[190] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 08 : 6[1d0] -> 5[1c0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 08 : 5[1c0] -> 1[180] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 08 : 3[1a0] -> 2[190] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 08 : 4[1b0] -> 0[170] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 08 : 2[190] -> 1[180] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 08 : 7[1e0] -> 4[1b0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 08 : 1[180] -> 5[1c0] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 08 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 08 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 09 : 3[1a0] -> 0[170] via P2P/IPC
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 09 : 0[170] -> 4[1b0] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 09 : 4[1b0] -> 7[1e0] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 09 : 2[190] -> 3[1a0] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 09 : 7[1e0] -> 6[1d0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 09 : 1[180] -> 2[190] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 09 : 6[1d0] -> 5[1c0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 09 : 5[1c0] -> 1[180] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 09 : 3[1a0] -> 2[190] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 09 : 4[1b0] -> 0[170] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 09 : 2[190] -> 1[180] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 09 : 7[1e0] -> 4[1b0] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 09 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 09 : 1[180] -> 5[1c0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 09 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 10 : 3[1a0] -> 7[1e0] via P2P/IPC
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 10 : 0[170] -> 1[180] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 10 : 4[1b0] -> 6[1d0] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 10 : 2[190] -> 0[170] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 10 : 7[1e0] -> 5[1c0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 10 : 1[180] -> 3[1a0] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 10 : 6[1d0] -> 2[190] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 10 : 5[1c0] -> 4[1b0] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 10 : 2[190] -> 6[1d0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 10 : 3[1a0] -> 1[180] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 10 : 7[1e0] -> 3[1a0] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 10 : 4[1b0] -> 5[1c0] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 10 : 6[1d0] -> 4[1b0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 10 : 1[180] -> 0[170] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 10 : 5[1c0] -> 7[1e0] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 11 : 2[190] -> 6[1d0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 11 : 3[1a0] -> 1[180] via P2P/IPC
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 11 : 0[170] -> 2[190] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 11 : 4[1b0] -> 5[1c0] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 11 : 7[1e0] -> 3[1a0] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 11 : 1[180] -> 0[170] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 11 : 6[1d0] -> 4[1b0] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 11 : 5[1c0] -> 7[1e0] via P2P/IPC
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Channel 11 : 2[190] -> 0[170] via P2P/IPC
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Channel 11 : 1[180] -> 3[1a0] via P2P/IPC
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO Channel 11 : 3[1a0] -> 7[1e0] via P2P/IPC
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Channel 11 : 7[1e0] -> 5[1c0] via P2P/IPC
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Channel 11 : 4[1b0] -> 6[1d0] via P2P/IPC
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Channel 11 : 6[1d0] -> 2[190] via P2P/IPC
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Channel 11 : 5[1c0] -> 4[1b0] via P2P/IPC
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO comm 0x5556c3cb6600 rank 0 nranks 8 cudaDev 0 busId 170 - Init COMPLETE
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO comm 0x55b93b608350 rank 1 nranks 8 cudaDev 1 busId 180 - Init COMPLETE
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO comm 0x56071c09e5d0 rank 3 nranks 8 cudaDev 3 busId 1a0 - Init COMPLETE
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO comm 0x56300985ece0 rank 2 nranks 8 cudaDev 2 busId 190 - Init COMPLETE
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO comm 0x55769c726180 rank 4 nranks 8 cudaDev 4 busId 1b0 - Init COMPLETE
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO comm 0x555e6cd50b10 rank 7 nranks 8 cudaDev 7 busId 1e0 - Init COMPLETE
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO comm 0x5637145deb70 rank 6 nranks 8 cudaDev 6 busId 1d0 - Init COMPLETE
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO 12 coll channels, 16 p2p channels, 2 p2p channels per peer
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO comm 0x55c303081380 rank 5 nranks 8 cudaDev 5 busId 1c0 - Init COMPLETE
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,4]<stdout>:algo-1:44:44 [4] NCCL INFO Trees [0] -1/-1/-1->4->7|7->4->-1/-1/-1 [1] -1/-1/-1->4->7|7->4->-1/-1/-1 [2] 7/-1/-1->4->0|0->4->7/-1/-1 [3] 7/-1/-1->4->0|0->4->7/-1/-1 [4] 6/-1/-1->4->5|5->4->6/-1/-1 [5] 5/-1/-1->4->6|6->4->5/-1/-1 [6] -1/-1/-1->4->7|7->4->-1/-1/-1 [7] -1/-1/-1->4->7|7->4->-1/-1/-1 [8] 7/-1/-1->4->0|0->4->7/-1/-1 [9] 7/-1/-1->4->0|0->4->7/-1/-1 [10] 6/-1/-1->4->5|5->4->6/-1/-1 [11] 5/-1/-1->4->6|6->4->5/-1/-1
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,5]<stdout>:algo-1:46:46 [5] NCCL INFO Trees [0] 6/-1/-1->5->1|1->5->6/-1/-1 [1] 6/-1/-1->5->1|1->5->6/-1/-1 [2] 1/-1/-1->5->6|6->5->1/-1/-1 [3] 1/-1/-1->5->6|6->5->1/-1/-1 [4] 4/-1/-1->5->7|7->5->4/-1/-1 [5] 7/-1/-1->5->4|4->5->7/-1/-1 [6] 6/-1/-1->5->1|1->5->6/-1/-1 [7] 6/-1/-1->5->1|1->5->6/-1/-1 [8] 1/-1/-1->5->6|6->5->1/-1/-1 [9] 1/-1/-1->5->6|6->5->1/-1/-1 [10] 4/-1/-1->5->7|7->5->4/-1/-1 [11] 7/-1/-1->5->4|4->5->7/-1/-1
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,6]<stdout>:algo-1:47:47 [6] NCCL INFO Trees [0] 7/-1/-1->6->5|5->6->7/-1/-1 [1] 7/-1/-1->6->5|5->6->7/-1/-1 [2] 5/-1/-1->6->7|7->6->5/-1/-1 [3] 5/-1/-1->6->7|7->6->5/-1/-1 [4] 2/-1/-1->6->4|4->6->2/-1/-1 [5] 4/-1/-1->6->2|2->6->4/-1/-1 [6] 7/-1/-1->6->5|5->6->7/-1/-1 [7] 7/-1/-1->6->5|5->6->7/-1/-1 [8] 5/-1/-1->6->7|7->6->5/-1/-1 [9] 5/-1/-1->6->7|7->6->5/-1/-1 [10] 2/-1/-1->6->4|4->6->2/-1/-1 [11] 4/-1/-1->6->2|2->6->4/-1/-1
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,7]<stdout>:algo-1:48:48 [7] NCCL INFO Trees [0] 4/-1/-1->7->6|6->7->4/-1/-1 [1] 4/-1/-1->7->6|6->7->4/-1/-1 [2] 6/-1/-1->7->4|4->7->6/-1/-1 [3] 6/-1/-1->7->4|4->7->6/-1/-1 [4] 5/-1/-1->7->3|3->7->5/-1/-1 [5] 3/-1/-1->7->5|5->7->3/-1/-1 [6] 4/-1/-1->7->6|6->7->4/-1/-1 [7] 4/-1/-1->7->6|6->7->4/-1/-1 [8] 6/-1/-1->7->4|4->7->6/-1/-1 [9] 6/-1/-1->7->4|4->7->6/-1/-1 [10] 5/-1/-1->7->3|3->7->5/-1/-1 [11] 3/-1/-1->7->5|5->7->3/-1/-1
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 00/12 :    0   3   2   1   5   6   7   4
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 01/12 :    0   3   2   1   5   6   7   4
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 02/12 :    0   4   7   6   5   1   2   3
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 03/12 :    0   4   7   6   5   1   2   3
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 04/12 :    0   1   3   7   5   4   6   2
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 05/12 :    0   2   6   4   5   7   3   1
# [1,1]<stdout>:algo-1:38:38 [1] NCCL INFO Trees [0] 5/-1/-1->1->2|2->1->5/-1/-1 [1] 5/-1/-1->1->2|2->1->5/-1/-1 [2] 2/-1/-1->1->5|5->1->2/-1/-1 [3] 2/-1/-1->1->5|5->1->2/-1/-1 [4] 3/-1/-1->1->0|0->1->3/-1/-1 [5] -1/-1/-1->1->3|3->1->-1/-1/-1 [6] 5/-1/-1->1->2|2->1->5/-1/-1 [7] 5/-1/-1->1->2|2->1->5/-1/-1 [8] 2/-1/-1->1->5|5->1->2/-1/-1 [9] 2/-1/-1->1->5|5->1->2/-1/-1 [10] 3/-1/-1->1->0|0->1->3/-1/-1 [11] -1/-1/-1->1->3|3->1->-1/-1/-1
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 06/12 :    0   3   2   1   5   6   7   4
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 07/12 :    0   3   2   1   5   6   7   4
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 08/12 :    0   4   7   6   5   1   2   3
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel 09/12 :    0   4   7   6   5   1   2   3
# [1,3]<stdout>:algo-1:42:42 [3] NCCL INFO threadThresholds 8/8/64 | 64/8/64 | 8/8/64
# [1,2]<stdout>:algo-1:40:40 [2] NCCL INFO Trees [0] 1/-1/-1->2->3|3->2->1/-1/-1 [1] 1/-1/-1->2->3|3->2->1/-1/-1 [2] 3/-1/-1->2->1|1->2->3/-1/-1 [3] 3/-1/-1->2->1|1->2->3/-1/-1 [4] -1/-1/-1->2->6|6->2->-1/-1/-1 [5] 6/-1/-1->2->0|0->2->6/-1/-1 [6] 1/-1/-1->2->3|3->2->1/-1/-1 [7] 1/-1/-1->2->3|3->2->1/-1/-1 [8] 3/-1/-1->2->1|1->2->3/-1/-1 [9] 3/-1/-1->2->1|1->2->3/-1/-1 [10] -1/-1/-1->2->6|6->2->-1/-1/-1 [11] 6/-1/-1->2->0|0->2->6/-1/-1
# [1,0]<stdout>:algo-1:509:509 [0] NCCL INFO Channel
# [1,0]<stdout>:batch 40250 -> MSE: 38057.3671875
# [1,0]<stdout>:batch 40300 -> MSE: 38098.96484375
# [1,0]<stdout>:batch 40350 -> MSE: 38134.08984375
# [1,0]<stdout>:batch 40400 -> MSE: 38172.59375
# [1,0]<stdout>:batch 40450 -> MSE: 38212.65625
# [1,0]<stdout>:batch 40500 -> MSE: 38248.1796875
# [1,0]<stdout>:batch 40550 -> MSE: 38283.41015625
# [1,0]<stdout>:batch 40600 -> MSE: 38320.796875
# [1,0]<stdout>:batch 40650 -> MSE: 38356.609375
# [1,0]<stdout>:batch 40700 -> MSE: 38393.74609375
# [1,0]<stdout>:batch 40750 -> MSE: 38426.73828125
# [1,0]<stdout>:batch 40800 -> MSE: 38457.69921875
# [1,0]<stdout>:batch 40850 -> MSE: 38496.671875
# [1,0]<stdout>:batch 40900 -> MSE: 38529.3359375
# [1,0]<stdout>:batch 40950 -> MSE: 38564.46875
# [1,0]<stdout>:batch 41000 -> MSE: 38600.35546875
# [1,0]<stdout>:batch 41050 -> MSE: 38646.515625
# [1,0]<stdout>:batch 41100 -> MSE: 38709.35546875
# [1,0]<stdout>:batch 41150 -> MSE: 38755.03515625
# [1,0]<stdout>:batch 41200 -> MSE: 38801.5625
# [1,0]<stdout>:batch 41250 -> MSE: 38843.17578125
# [1,0]<stdout>:batch 41300 -> MSE: 38886.53515625
# [1,0]<stdout>:batch 41350 -> MSE: 38932.4609375
# [1,0]<stdout>:batch 41400 -> MSE: 38978.6015625
# [1,0]<stdout>:batch 41450 -> MSE: 39016.4375
# [1,0]<stdout>:batch 41500 -> MSE: 39056.0703125
# [1,0]<stdout>:batch 41550 -> MSE: 39094.33203125
# [1,0]<stdout>:batch 41600 -> MSE: 39132.65234375
# [1,0]<stdout>:batch 41650 -> MSE: 39176.57421875
# [1,0]<stdout>:batch 41700 -> MSE: 39228.9609375
# [1,0]<stdout>:batch 41750 -> MSE: 39280.57421875
# [1,0]<stdout>:batch 41800 -> MSE: 39326.31640625
# [1,0]<stdout>:batch 41850 -> MSE: 39369.703125
# [1,0]<stdout>:batch 41900 -> MSE: 39410.19140625
# [1,0]<stdout>:batch 41950 -> MSE: 39456.07421875
# [1,0]<stdout>:batch 42000 -> MSE: 39508.98828125
# [1,0]<stdout>:batch 42050 -> MSE: 39567.8671875
# [1,0]<stdout>:batch 42100 -> MSE: 39621.171875
# [1,0]<stdout>:batch 42150 -> MSE: 39676.40625
# [1,0]<stdout>:batch 42200 -> MSE: 39735.55859375
# [1,0]<stdout>:batch 42250 -> MSE: 39787.375
# [1,0]<stdout>:batch 42300 -> MSE: 39824.8203125
# [1,0]<stdout>:batch 42350 -> MSE: 39884.3828125
# [1,0]<stdout>:batch 42400 -> MSE: 39933.37109375
# [1,0]<stdout>:batch 42450 -> MSE: 39985.21484375
# [1,0]<stdout>:batch 42500 -> MSE: 40041.7578125
# [1,0]<stdout>:batch 42550 -> MSE: 40097.25390625
# [1,0]<stdout>:batch 42600 -> MSE: 40147.67578125
# [1,0]<stdout>:batch 42650 -> MSE: 40206.46875
# [1,0]<stdout>:batch 42700 -> MSE: 40261.43359375
# [1,0]<stdout>:batch 42750 -> MSE: 40319.2265625
# [1,0]<stdout>:batch 42800 -> MSE: 40369.34375
# [1,0]<stdout>:batch 42850 -> MSE: 40426.6953125
# [1,0]<stdout>:batch 42900 -> MSE: 40492.984375
# [1,0]<stdout>:batch 42950 -> MSE: 40562.9453125
# [1,0]<stdout>:batch 43000 -> MSE: 40632.171875
# [1,0]<stdout>:batch 43050 -> MSE: 40714.625
# [1,0]<stdout>:batch 43100 -> MSE: 40800.95703125
# [1,0]<stdout>:batch 43150 -> MSE: 40862.33203125
# [1,0]<stdout>:batch 43200 -> MSE: 40918.953125
# [1,0]<stdout>:batch 43250 -> MSE: 40965.7421875
# [1,0]<stdout>:batch 43300 -> MSE: 41006.41015625
# [1,0]<stdout>:batch 43350 -> MSE: 41040.28515625
# [1,0]<stdout>:batch 43400 -> MSE: 41075.08203125
# [1,0]<stdout>:batch 43450 -> MSE: 41110.88671875
# [1,0]<stdout>:batch 43500 -> MSE: 41153.7109375
# [1,0]<stdout>:batch 43550 -> MSE: 41204.7421875
# [1,0]<stdout>:batch 43600 -> MSE: 41264.5078125
# [1,0]<stdout>:batch 43650 -> MSE: 41308.66796875
# [1,0]<stdout>:batch 43700 -> MSE: 41363.57421875
# [1,0]<stdout>:batch 43750 -> MSE: 41424.76953125
# [1,0]<stdout>:batch 43800 -> MSE: 41476.85546875
# [1,0]<stdout>:batch 43850 -> MSE: 41525.875
# [1,0]<stdout>:batch 43900 -> MSE: 41574.4765625
# [1,0]<stdout>:batch 43950 -> MSE: 41627.81640625
# [1,0]<stdout>:batch 44000 -> MSE: 41676.37890625
# [1,0]<stdout>:batch 44050 -> MSE: 41732.5390625
# [1,0]<stdout>:batch 44100 -> MSE: 41794.6796875
# [1,0]<stdout>:batch 44150 -> MSE: 41846.09765625
# [1,0]<stdout>:batch 44200 -> MSE: 41895.4140625
# [1,0]<stdout>:batch 44250 -> MSE: 41944.34375
# [1,0]<stdout>:batch 44300 -> MSE: 42001.60546875
# [1,0]<stdout>:batch 44350 -> MSE: 42041.81640625
# [1,0]<stdout>:batch 44400 -> MSE: 42091.171875
# [1,0]<stdout>:batch 44450 -> MSE: 42148.73046875
# [1,0]<stdout>:batch 44500 -> MSE: 42184.5
# [1,0]<stdout>:batch 44550 -> MSE: 42235.6953125
# [1,0]<stdout>:batch 44600 -> MSE: 42287.3359375
# [1,0]<stdout>:batch 44650 -> MSE: 42337.578125
# [1,0]<stdout>:batch 44700 -> MSE: 42373.328125
# [1,0]<stdout>:batch 44750 -> MSE: 42407.8984375
# [1,0]<stdout>:batch 44800 -> MSE: 42439.421875
# [1,0]<stdout>:batch 44850 -> MSE: 42485.66015625
# [1,0]<stdout>:batch 44900 -> MSE: 42518.83203125
# [1,0]<stdout>:batch 44950 -> MSE: 42561.03125
# [1,0]<stdout>:batch 45000 -> MSE: 42604.81640625

# %% [markdown]
# Distributed mode gives us an MSE of 0.0147 with a time of 4258 seconds.  Compared to 6931 seconds without distributed training, that's a 38% speedup.

# %% [markdown]
# # HPO

# %%
from sagemaker.tuner import (
    IntegerParameter,
    CategoricalParameter,
    ContinuousParameter,
    HyperparameterTuner,
)
hyperparameter_ranges = {
    "eta": ContinuousParameter(0, 1),
    "min_child_weight": ContinuousParameter(1, 10),
    "alpha": ContinuousParameter(0, 2),
    "max_depth": IntegerParameter(1, 10),
}

# %%
objective_metric_name = "validation:rmse"

# %%
estimator_hpo = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=sagemaker.get_execution_role(),
                                          instance_count=1, 
                                          instance_type='ml.m5.12xlarge', 
                                          volume_size=200, # 5 GB 
                                          output_path=output_path)

# %%
tuner = HyperparameterTuner(
    estimator_hpo, objective_metric_name, hyperparameter_ranges, max_jobs=10, max_parallel_jobs=2,
    objective_type = 'Minimize'
)

# %%
tuner.fit({'train': train_input, 'validation': validation_input})

# %%
tuning_job_name = tuner.latest_tuning_job.name

# %%
import pandas as pd

tuner_results = sagemaker.HyperparameterTuningJobAnalytics(tuning_job_name)

full_df = tuner_results.dataframe()

if len(full_df) > 0:
    df = full_df[full_df["FinalObjectiveValue"] > -float("inf")]
    if len(df) > 0:
        df = df.sort_values("FinalObjectiveValue", ascending=True)
        print("Number of training jobs with valid objective: %d" % len(df))
        print({"lowest": min(df["FinalObjectiveValue"]), "highest": max(df["FinalObjectiveValue"])})
        pd.set_option("display.max_colwidth", -1)  # Don't truncate TrainingJobName
    else:
        print("No training jobs have reported valid results yet.")

df

# %% [markdown]
# Best RMSE is 1.335 with max_depth = 2, alpha = 1.59, eta = 0.99, min_child_weight = 5.90.

# %% [markdown]
# ### Experiments

# %%
import boto3
sm = boto3.client("sagemaker")

# %%
experiment_name = "example-experiment-with-tuning-jobs"
trial_name = tuning_job_name + "-trial"

print(f"Associate all training jobs created by {tuning_job_name} with trial {trial_name}")

# %%
# create the experiment if it doesn't exist
try:
    experiment = Experiment.load(experiment_name=experiment_name)
except Exception as ex:
    if "ResourceNotFound" in str(ex):
        experiment = Experiment.create(experiment_name=experiment_name)


# create the trial if it doesn't exist
try:
    trial = Trial.load(trial_name=trial_name)
except Exception as ex:
    if "ResourceNotFound" in str(ex):
        trial = Trial.create(experiment_name=experiment_name, trial_name=trial_name)

# %%
# !pip install sagemaker-experiments

# %%
from smexperiments.search_expression import Filter, Operator, SearchExpression
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
tuning_job = tuner.describe()
creation_time = tuning_job["CreationTime"]
creation_time = creation_time.astimezone(timezone.utc)
creation_time = creation_time.strftime("%Y-%m-%dT%H:%M:%SZ")

created_after_filter = Filter(
    name="CreationTime",
    operator=Operator.GREATER_THAN_OR_EQUAL,
    value=str(creation_time),
)

# the training job names contain the tuning job name (and the training job name is in the source arn)
source_arn_filter = Filter(
    name="TrialComponentName", operator=Operator.CONTAINS, value=tuning_job_name
)
source_type_filter = Filter(
    name="Source.SourceType", operator=Operator.EQUALS, value="SageMakerTrainingJob"
)

search_expression = SearchExpression(
    filters=[created_after_filter, source_arn_filter, source_type_filter]
)

# search iterates over every page of results by default
trial_component_search_results = list(
    TrialComponent.search(search_expression=search_expression, sagemaker_boto_client=sm)
)
print(f"Found {len(trial_component_search_results)} trial components.")

# %%
# associate the trial components with the trial
import time
for tc in trial_component_search_results:
    print(f"Associating trial component {tc.trial_component_name} with trial {trial.trial_name}.")
    trial.add_trial_component(tc.trial_component_name)
    # sleep to avoid throttling
    time.sleep(0.5)

# %%
from sagemaker.analytics import ExperimentAnalytics
sess = boto3.Session()
sm = sess.client("sagemaker")
sagemaker_session = Session(sess)

trial_component_analytics = ExperimentAnalytics(
    sagemaker_session=sagemaker_session, experiment_name=experiment_name
)
trial_comp_ds_jobs = trial_component_analytics.dataframe()
trial_comp_ds_jobs

# %%
trial_comp_ds_jobs = trial_comp_ds_jobs.sort_values("validation:rmse - Last", ascending=False)
trial_comp_ds_jobs[["TrialComponentName", "validation:rmse - Last", "max_depth"]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

trial_comp_ds_jobs["col_names"] = (
    trial_comp_ds_jobs["max_depth"].astype("str")
    + "-" + trial_comp_ds_jobs["alpha"].astype("str")
    + "-" + trial_comp_ds_jobs["eta"].astype("str")
    + "-" + trial_comp_ds_jobs["min_child_weight"].astype("str")
)

# %%
sns.set(style="dark")
sns.stripplot(data = trial_comp_ds_jobs, x="validation:rmse - Last", y = "col_names")

# %% [markdown]
# ## Pipe mode

# %%
# set an output path where the trained model will be saved
m_prefix = 'baseline-pipe'
output_path = 's3://{}/{}/{}/output'.format(s3_bucket, m_prefix, 'xgboost')

# this line automatically looks for the XGBoost image URI and builds an XGBoost container.
# specify the repo_version depending on your preference.
xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.2-1")

# construct a SageMaker estimator that calls the xgboost-container
estimator = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=sagemaker.get_execution_role(),
                                          instance_count=1, 
                                          instance_type='ml.m5.12xlarge', 
                                          volume_size=200, # 5 GB 
                                          output_path=output_path,
                                         train_use_spot_instances=False,
                                          input_mode="Pipe")



# execute the XGBoost training job
estimator.fit({'train': ptrain, 'validation': pvalid})

# %% [markdown]
# Billable time was 53 seconds with pipe mode.

# %% [markdown]
# ## Spot

# %%
m_prefix = 'spot'
output_path = 's3://{}/{}/{}/output'.format(s3_bucket, m_prefix, 'xgboost')

# this line automatically looks for the XGBoost image URI and builds an XGBoost container.
# specify the repo_version depending on your preference.
xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.2-1")

# construct a SageMaker estimator that calls the xgboost-container
estimator = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=sagemaker.get_execution_role(),
                                          instance_count=1, 
                                          instance_type='ml.m5.12xlarge', 
                                          volume_size=200, # 5 GB 
                                          output_path=output_path,
                                         train_use_spot_instances=True,
                                         train_max_run=3600,
                                         train_max_wait=3600)



# execute the XGBoost training job
estimator.fit({'train': train_input, 'validation': validation_input})

# %% [markdown]
# Spot savings: 64.6%
#
#     Managed Spot Training savings: 64.6%
